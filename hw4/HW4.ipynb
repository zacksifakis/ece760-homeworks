# %% [markdown]
# Question 3.1

# %%
# Create the training set
import os
import numpy as np

training_set = []
langs = ["e", "j", "s"]

# Iterate through each language (e, j, s)
for lang in langs:
    # Iterate through each document number (0-9)
    for i in range(10):
        # Generate the file name using the lang and number
        file_name = f"{lang}{i}.txt"

        # Open the file and read its contents
        with open(file_name, "r") as file:
            content = file.read().replace('\n', '')  # Remove newline characters

        # Add the document content to the training set along with its lang
        training_set.append((content, lang))

# Probability of English using additive smoothing

# Count the number of documents in the training set with lang = e
num_e = sum([1 for doc in training_set if doc[1] == "e"])
p_e = (num_e + 0.5) / (len(training_set) + len(langs) * 0.5)
log_p_e = np.log(p_e)
print(f"Prior probability p(y = e) = {p_e}")

# Do the same for Japanese and Spanish
num_j = sum([1 for doc in training_set if doc[1] == "j"])
p_j = (num_j + 0.5) / (len(training_set) + len(langs) * 0.5)
log_p_j = np.log(p_j)
print(f"Prior probability p(y = j) = {p_j}")

num_s = sum([1 for doc in training_set if doc[1] == "s"])
p_s = (num_s + 0.5) / (len(training_set) + len(langs) * 0.5)
log_p_s = np.log(p_s)
print(f"Prior probability p(y = s) = {p_s}")
# Out:
# Prior probability p(y = e) = 0.3333333333333333
# Prior probability p(y = j) = 0.3333333333333333
# Prior probability p(y = s) = 0.3333333333333333

# %% [markdown]
# Question 3.2

# %%
# Create a set of characters (a-z and space)
c = list("abcdefghijklmnopqrstuvwxyz ")

print("\n\n Class conditional probabilities for English documents:")
# Initialize an empty dictionary to store the probabilities of each character
theta_e= {}
log_theta_e = {}

for char in c:
    #count number of characters in english documents
    num_char_e = sum([doc[0].count(char) for doc in training_set if doc[1] == "e"])
    #count total number of characters in english documents
    total_char_e = sum([len(doc[0]) for doc in training_set if doc[1] == "e"])
    #calculate probability of character in english documents
    p_char_e = (num_char_e + 0.5) / (total_char_e + len(c) * 0.5)
    # add the probability to the dictionary
    theta_e[char] = p_char_e
    log_theta_e[char] = np.log(p_char_e)

thetas_e = sorted(theta_e.keys())
thetas_e.remove(' ')
thetas_e.append(' ')

# Iterate over the sorted keys and print each key and its associated value
for key in thetas_e:
    print(f'{key}: {theta_e[key]}')

thetas_e = [theta_e[key] for key in thetas_e]
print(thetas_e)
# Out:
#  Class conditional probabilities for English documents:
# a: 0.0601685114819098
# b: 0.011134974392863043
# c: 0.021509995043779945
# d: 0.021972575582355856
# e: 0.1053692383941847
# f: 0.018932760614571286
# g: 0.017478936064761277
# h: 0.047216256401784236
# i: 0.055410540227986124
# j: 0.001420783082768875
# k: 0.0037336857756484387
# l: 0.028977366595076822
# m: 0.020518751032545846
# n: 0.057921691723112505
# o: 0.06446390219725756
# p: 0.01675202378985627
# q: 0.0005617049396993227
# r: 0.053824549810011564
# s: 0.06618205848339666
# t: 0.08012555757475633
# u: 0.026664463902197257
# v: 0.009284652238559392
# w: 0.015496448042293078
# x: 0.001156451346439782
# y: 0.013844374690236246
# z: 0.0006277878737815959
#  : 0.1792499586981662
# ...

# %% [markdown]
# Question 3.3

# %%
print("\n\n Class conditional probabilities for Japanese documents:")
# Initialize an empty dictionary to store the probabilities of each character
theta_j= {}
log_theta_j = {}

for char in c:
    #count number of characters in japanese documents
    num_char_j = sum([doc[0].count(char) for doc in training_set if doc[1] == "j"])
    #count total number of characters in japanese documents
    total_char_j = sum([len(doc[0]) for doc in training_set if doc[1] == "j"])

    #calculate probability of character in japanese documents
    p_char_j = (num_char_j + 0.5) / (total_char_j + len(c) * 0.5)
    # add the probability to the dictionary
    theta_j[char] = p_char_j
    log_theta_j[char] = np.log(p_char_j)

thetas_j = sorted(theta_j.keys())
thetas_j.remove(' ')
thetas_j.append(' ')

# Iterate over the sorted keys and print each key and its associated value
for key in thetas_j:
    print(f'{key}: {theta_j[key]}')

thetas_j = [theta_j[key] for key in thetas_j]
print(thetas_j)


print("\n\n Class conditional probabilities for Spanish documents:")
# Initialize an empty dictionary to store the probabilities of each character
theta_s= {}
log_theta_s = {}

for char in c:
    #count number of characters in spanish documents
    num_char_s = sum([doc[0].count(char) for doc in training_set if doc[1] == "s"])
    #count total number of characters in spanish documents
    total_char_s = sum([len(doc[0]) for doc in training_set if doc[1] == "s"])

    #calculate probability of character in spanish documents
    p_char_s = (num_char_s + 0.5) / (total_char_s + len(c) * 0.5)
    # add the probability to the dictionary
    theta_s[char] = p_char_s
    log_theta_s[char] = np.log(p_char_s)

# Sort the keys in the dictionary
thetas_s = sorted(theta_s.keys())
thetas_s.remove(' ')
thetas_s.append(' ')

# Iterate over the sorted keys and print each key and its associated value
for key in thetas_s:
    print(f'{key}: {theta_s[key]}')

thetas_s = [theta_s[key] for key in thetas_s]
print(thetas_s)
# Out:
#  Class conditional probabilities for Japanese documents:
# a: 0.1317656102589189
# b: 0.010866906600510151
# c: 0.005485866033054963
# d: 0.01722631818022992
# e: 0.06020475907613823
# f: 0.003878542227191726
# g: 0.014011670568503443
# h: 0.03176211607673224
# i: 0.09703343932352633
# j: 0.0023411020650616725
# k: 0.05740941332681086
# l: 0.001432614696530277
# m: 0.03979873510604843
# n: 0.05671057688947902
# o: 0.09116321324993885
# p: 0.0008735455466648031
# q: 0.00010482546559977637
# r: 0.04280373178657535
# s: 0.0421747789929767
# t: 0.056990111464411755
# u: 0.07061742199238269
# v: 0.0002445927530661449
# w: 0.01974212935462455
# x: 3.4941821866592126e-05
# y: 0.01415143785596981
# z: 0.00772214263251686
#  : 0.12344945665466997
# ...

# %% [markdown]
# Question 3.4

# %%
with open("e10.txt", "r") as file:
    x = file.read().replace('\n', '')

# Creating a bag of words for the test document by counting the appearance of each character in the document
bow_x = {}
for char in c:
    bow_x[char] = x.count(char)

print(bow_x)

# Count vector
count_vector = [bow_x[char] for char in sorted(bow_x, key=lambda k: (k == ' ', k))]
print(count_vector)
# Out:
# {'a': 164, 'b': 32, 'c': 53, 'd': 57, 'e': 311, 'f': 55, 'g': 51, 'h': 140, 'i': 140, 'j': 3, 'k': 6, 'l': 85, 'm': 64, 'n': 139, 'o': 182, 'p': 53, 'q': 3, 'r': 141, 's': 186, 't': 225, 'u': 65, 'v': 31, 'w': 47, 'x': 4, 'y': 38, 'z': 2, ' ': 498}
# [164, 32, 53, 57, 311, 55, 51, 140, 140, 3, 6, 85, 64, 139, 182, 53, 3, 141, 186, 225, 65, 31, 47, 4, 38, 2, 498]

# %% [markdown]
# Question 3.5

# %%
thetas_e = np.array(thetas_e)
thetas_j = np.array(thetas_j)
thetas_s = np.array(thetas_s)

thetas_e_new = thetas_e ** count_vector
thetas_j_new = thetas_j ** count_vector
thetas_s_new = thetas_s ** count_vector

p_x_y_e = np.prod(thetas_e_new)
p_x_y_j = np.prod(thetas_j_new)
p_x_y_s = np.prod(thetas_s_new)

log_thetas_e = np.log(thetas_e)
log_thetas_j = np.log(thetas_j)
log_thetas_s = np.log(thetas_s)

log_p_x_y_e = np.sum(count_vector * log_thetas_e)
log_p_x_y_j = np.sum(count_vector * log_thetas_j)
log_p_x_y_s = np.sum(count_vector * log_thetas_s)

p_x_y_e_new = np.exp(log_p_x_y_e)
p_x_y_j_new = np.exp(log_p_x_y_j)
p_x_y_s_new= np.exp(log_p_x_y_s)


print(f"log probability of p(x|y=e) = {log_p_x_y_e:.10f}")
print(f"log probability of p(x|y=j) = {log_p_x_y_j:.10f}")
print(f"log probability of p(x|y=s) = {log_p_x_y_s:.10f}")

print(f"Probability of p(x|y=e) = exp({log_p_x_y_e:.5f})")
print(f"Probability of p(x|y=j) = exp({log_p_x_y_j:.5f})")
print(f"Probability of p(x|y=s) = exp({log_p_x_y_s:.5f})")
# Out:
# log probability of p(x|y=e) = -7841.8654470606
# log probability of p(x|y=j) = -8771.4330790750
# log probability of p(x|y=s) = -8467.2820440106
# Probability of p(x|y=e) = exp(-7841.86545)
# Probability of p(x|y=j) = exp(-8771.43308)
# Probability of p(x|y=s) = exp(-8467.28204)

# %% [markdown]
# Question 3.6

# %%
p_y_e_x = p_x_y_e_new * p_e
p_y_e_x_log = log_p_x_y_e + np.log(p_e)

p_y_j_x = p_x_y_j_new * p_j
p_y_j_x_log = log_p_x_y_j + np.log(p_j)

p_y_s_x = p_x_y_s_new * p_s
p_y_s_x_log = log_p_x_y_s + np.log(p_s)


print(f"log probability of p(y=e|x) ∝ {p_y_e_x_log:.5f}")
print(f"log probability of p(y=j|x) ∝ {p_y_j_x_log:.5f}")
print(f"log probability of p(y=s|x) ∝ {p_y_s_x_log:.5f}")

print(f"Probability of p(y=e|x) ∝ exp({p_y_e_x_log:.5f})")
print(f"Probability of p(y=j|x) ∝ exp({p_y_j_x_log:.5f})")
print(f"Probability of p(y=s|x) ∝ exp({p_y_s_x_log:.5f})")
# Out:
# log probability of p(y=e|x) ∝ -7842.96406
# log probability of p(y=j|x) ∝ -8772.53169
# log probability of p(y=s|x) ∝ -8468.38066
# Probability of p(y=e|x) ∝ exp(-7842.96406)
# Probability of p(y=j|x) ∝ exp(-8772.53169)
# Probability of p(y=s|x) ∝ exp(-8468.38066)
# Predicted class : -7842.964059349303

# %% [markdown]
# Question 3.7

# %%
# Initialization of 3x3 confusion matrix
confusion_matrix = np.zeros((3, 3))

# Dictionary to map languages to indices
lang_dict = {"e": 0, "j": 1, "s": 2}

# Iteratation over the test documents
for i in range(10, 20):
    for lang in langs:
        # Generate the file name
        file_name = f"{lang}{i}.txt"

        # Open the file and read its contents
        with open(file_name, "r") as file:
            x = file.read().replace('\n', '')

        # Create a bag of words for the test document
        bow_x = {char: x.count(char) for char in c}

        # Create a count vector
        count_vector = [bow_x[char] for char in sorted(bow_x, key=lambda k: (k == ' ', k))]

        # Calculate log probabilities
        log_p_x_y_e = np.sum(count_vector * log_thetas_e)
        log_p_x_y_j = np.sum(count_vector * log_thetas_j)
        log_p_x_y_s = np.sum(count_vector * log_thetas_s)

        # Calculate posteriors
        p_y_e_x_log = log_p_x_y_e + np.log(p_e)
        p_y_j_x_log = log_p_x_y_j + np.log(p_j)
        p_y_s_x_log = log_p_x_y_s + np.log(p_s)

        # Predict the language
        predicted_lang = np.argmax([p_y_e_x_log, p_y_j_x_log, p_y_s_x_log])

        # Update the confusion matrix
        confusion_matrix[predicted_lang, lang_dict[lang]] += 1

print(f"Confusion matrix: \n {confusion_matrix}")
# Out:
# Confusion matrix:
#  [[10.  0.  0.]
#  [ 0. 10.  0.]
#  [ 0.  0. 10.]]

# %% [markdown]
# Question 4.2

# %%
# !pip install idx2numpy


import numpy as np
import idx2numpy
import matplotlib.pyplot as plt

def softmax(x):
    e_x = np.exp(x - np.max(x, axis=1, keepdims=True))
    return e_x / np.sum(e_x, axis=1, keepdims=True)


def sigmoid(x):
    return 1 / (1 + np.exp(-x))


def cross_entropy_loss(y, y_hat):
    delta = 1e-7
    return -np.sum(y*np.log(y_hat+delta))


def sigmoid_grad(x):
    return (1.0 - x) * x


class NeuralNetwork:
    def __init__(self, input_size, hidden_size, output_size):
        self.params = {}
        self.params['W1'] = np.random.randn(input_size, hidden_size)
        self.params['W2'] = np.random.randn(hidden_size, output_size)

    def forward(self, x):
        W1, W2 = self.params['W1'], self.params['W2']
        z1 = np.dot(x, W1)
        h1 = sigmoid(z1)
        z2 = np.dot(h1, W2)
        y_hat = softmax(z2)

        return y_hat, h1

    def loss(self, x, y):
        y_hat, _ = self.forward(x)
        loss = cross_entropy_loss(y, y_hat)
        return loss

    def accuracy(self, x, y):
        y_hat, _ = self.forward(x)
        y_hat = np.argmax(y_hat, axis=1)
        accuracy = np.sum(y_hat == y) / float(x.shape[0])
        return accuracy

    def backprop(self, x, y):
        grads = {}
        W1, W2 = self.params['W1'], self.params['W2']
        y_hat, h1 = self.forward(x)

        delta3 = -(y - y_hat)
        grads['W2'] = np.dot(h1.T, delta3)
        delta2 = np.dot(delta3, W2.T) * sigmoid_grad(h1)
        grads['W1'] = np.dot(x.T, delta2)

        return grads

test_errors = []
train_losses = []
test_accuracies = []
test_losses = []

def train_model(nn, train_images, train_labels_onehot, test_images, test_labels, learning_rate, batch_size, epochs):
    num_samples = train_images.shape[0]
    num_batches = num_samples // batch_size

    for epoch in range(epochs):
        train_loss = 0
        for i in range(num_batches):
            start = i * batch_size
            end = start + batch_size
            x_batch = train_images[start:end]
            y_batch = train_labels_onehot[start:end]

            loss = nn.loss(x_batch, y_batch)
            train_loss += loss

            grads = nn.backprop(x_batch, y_batch)
            for key in ('W1', 'W2'):
                nn.params[key] -= learning_rate * grads[key]

        train_loss /= num_batches
        train_losses.append(train_loss)

        test_error = 1 - nn.accuracy(test_images, test_labels)
        test_errors.append(test_error)

        test_loss = nn.loss(test_images, np.eye(output_size)[test_labels]) / len(test_images)
        test_losses.append(test_loss)


        test_accuracy = nn.accuracy(test_images, test_labels)
        test_accuracies.append(test_accuracy)

        print(f"Epoch {epoch + 1}/{epochs}")
        print(f"Loss: {train_loss}")
        print(f"Training Accuracy: {nn.accuracy(train_images, train_labels)}")
        print(f"Test Error: {test_loss}")
        print(f"Test Accuracy: {test_accuracy}")



# Load training images
train_images = idx2numpy.convert_from_file('train-images.idx3-ubyte')
print(train_images.shape)

# Load training labels
train_labels = idx2numpy.convert_from_file('train-labels.idx1-ubyte')
print(train_labels.shape)

# Load test images
test_images = idx2numpy.convert_from_file('t10k-images.idx3-ubyte')
print(test_images.shape)

# Load test labels
test_labels = idx2numpy.convert_from_file('t10k-labels.idx1-ubyte')
print(test_labels.shape)

# Reshape and normalize images
train_images = train_images.reshape(-1, 28*28) / 255.0
test_images = test_images.reshape(-1, 28*28) / 255.0

# Initialize network
input_size = 784
hidden_size = 300
output_size = 10
nn = NeuralNetwork(input_size, hidden_size, output_size)

# Convert labels to one-hot encoding
train_labels_onehot = np.eye(output_size)[train_labels]

# Parameters
learning_rate = 1e-3
batch_size = 32
epochs = 50

train_model(nn, train_images, train_labels_onehot, test_images, test_labels, learning_rate, batch_size, epochs)

plt.plot(range(1, epochs+1), train_losses)
plt.title('Training Loss vs. Epoch')
plt.xlabel('Epoch')
plt.ylabel('Training Loss')
plt.show()

plt.plot(range(1, epochs+1), test_losses)
plt.title('Test Loss vs. Epoch')
plt.xlabel('Epoch')
plt.ylabel('Test Loss')
plt.show()

plt.plot(range(1, epochs+1), test_accuracies)
plt.title('Test Accuracy vs. Epoch')
plt.xlabel('Epoch')
plt.ylabel('Test Accuracy')
plt.show()
# Out:
# ...
# (60000, 28, 28)
# (60000,)
# (10000, 28, 28)
# (10000,)
# Epoch 1/50
# Loss: 65.57397596862761
# Training Accuracy: 0.7967166666666666
# Test Error: 1.024962589725144
# Test Accuracy: 0.799
# Epoch 2/50
# Loss: 28.335688342367966
# Training Accuracy: 0.8452833333333334
# Test Error: 0.7659761466524835
# Test Accuracy: 0.8411
# Epoch 3/50
# Loss: 22.071680980785345
# Training Accuracy: 0.8672666666666666
# Test Error: 0.6531030208842614
# Test Accuracy: 0.86
# Epoch 4/50
# Loss: 18.74300685888293
# Training Accuracy: 0.8804833333333333
# Test Error: 0.5844120208326257
# Test Accuracy: 0.871
# Epoch 5/50
# Loss: 16.50372994172631
# Training Accuracy: 0.8898666666666667
# Test Error: 0.5364596839184894
# Test Accuracy: 0.8806
# Epoch 6/50
# Loss: 14.835504976302786
# Training Accuracy: 0.8975166666666666
# Test Error: 0.5001993851758071
# Test Accuracy: 0.8873
# Epoch 7/50
# Loss: 13.525495008358298
# Training Accuracy: 0.9039
# Test Error: 0.4716066605235762
# Test Accuracy: 0.8917
# ...

# %% [markdown]
# Question 4.3

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torchvision import datasets, transforms
import matplotlib.pyplot as plt

transform = transforms.ToTensor()

train_dataset = datasets.MNIST(root = './mnist_data/',
                               train = True,
                               transform = transform,
                               download = True)
test_dataset = datasets.MNIST(root = './mnist_data/',
                              train = False,
                              transform = transform)

batch_size = 32
train_loader = torch.utils.data.DataLoader(dataset = train_dataset,
                                           batch_size = batch_size,
                                           shuffle = True)
test_loader = torch.utils.data.DataLoader(dataset = test_dataset,
                                          batch_size = batch_size,
                                          shuffle = False)

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(784, 300, bias = False)
        self.fc2 = nn.Linear(300, 10, bias = False)

    def forward(self, x):
        x = x.view(-1, 784) # Flatten the input images from the dataset
        x = F.sigmoid(self.fc1(x))
        x = self.fc2(x)
        return x
model = Net()

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

num_epochs = 30
train_losses = []
test_losses = []
test_accuracies = []

for epoch in range(num_epochs):
    train_loss = 0.0
    for i, (images, labels) in enumerate(train_loader):
        outputs = model(images)
        loss = criterion(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
    else:
        test_loss = 0.0
        accuracy = 0
        with torch.no_grad():
            model.eval()
            for images, labels in test_loader:
                log_ps = model(images)
                test_loss += criterion(log_ps, labels).item()

                ps = log_ps
                top_p, top_class = ps.topk(1, dim=1)
                equals = top_class == labels.view(*top_class.shape)
                accuracy += torch.mean(equals.type(torch.FloatTensor))
        model.train()

        test_accuracy = accuracy/len(test_loader)
        test_accuracies.append(test_accuracy.item())

        train_losses.append(train_loss/len(train_loader))
        test_losses.append(test_loss/len(test_loader))

        print("Epoch: {}/{}.. ".format(epoch+1, num_epochs),
              "Training Loss: {:.3f}.. ".format(train_loss/len(train_loader)),
              "Test Loss: {:.3f}.. ".format(test_loss/len(test_loader)),
              "Test Accuracy: {:.3f}".format(test_accuracy))

plt.figure(figsize=(10, 5))
plt.plot(range(1, num_epochs+1), test_accuracies, color='blue')
plt.title('Test Accuracy vs. Epoch')
plt.xlabel('Epochs')
plt.ylabel('Test Accuracy')
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(range(1, num_epochs+1), test_losses, color='blue')
plt.title('Test Loss vs. Epoch')
plt.xlabel('Epochs')
plt.ylabel('Test Loss')
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(range(1, num_epochs+1), train_losses, color='blue')
plt.title('Training Loss vs. Epoch')
plt.xlabel('Epochs')
plt.ylabel('Training Loss')
plt.show()
# Out:
# Epoch: 1/30..  Training Loss: 1.829..  Test Loss: 1.198..  Test Accuracy: 0.773
# Epoch: 2/30..  Training Loss: 0.886..  Test Loss: 0.664..  Test Accuracy: 0.847
# Epoch: 3/30..  Training Loss: 0.591..  Test Loss: 0.505..  Test Accuracy: 0.874
# Epoch: 4/30..  Training Loss: 0.484..  Test Loss: 0.434..  Test Accuracy: 0.889
# Epoch: 5/30..  Training Loss: 0.430..  Test Loss: 0.392..  Test Accuracy: 0.895
# Epoch: 6/30..  Training Loss: 0.397..  Test Loss: 0.367..  Test Accuracy: 0.898
# Epoch: 7/30..  Training Loss: 0.375..  Test Loss: 0.349..  Test Accuracy: 0.901
# Epoch: 8/30..  Training Loss: 0.359..  Test Loss: 0.338..  Test Accuracy: 0.904
# Epoch: 9/30..  Training Loss: 0.347..  Test Loss: 0.327..  Test Accuracy: 0.906
# Epoch: 10/30..  Training Loss: 0.338..  Test Loss: 0.319..  Test Accuracy: 0.909
# Epoch: 11/30..  Training Loss: 0.330..  Test Loss: 0.312..  Test Accuracy: 0.910
# Epoch: 12/30..  Training Loss: 0.323..  Test Loss: 0.308..  Test Accuracy: 0.912
# ...

# %% [markdown]
# Question 4.4 i)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torchvision import datasets, transforms
import matplotlib.pyplot as plt

transform = transforms.ToTensor()

train_dataset = datasets.MNIST(root = './mnist_data/',
                               train = True,
                               transform = transform,
                               download = True)
test_dataset = datasets.MNIST(root = './mnist_data/',
                              train = False,
                              transform = transform)

batch_size = 32
train_loader = torch.utils.data.DataLoader(dataset = train_dataset,
                                           batch_size = batch_size,
                                           shuffle = True)
test_loader = torch.utils.data.DataLoader(dataset = test_dataset,
                                          batch_size = batch_size,
                                          shuffle = False)

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(784, 300, bias = False)
        self.fc2 = nn.Linear(300, 10, bias = False)

        self.init_weights()

    def init_weights(self):
        nn.init.constant_(self.fc1.weight, 0)
        nn.init.constant_(self.fc2.weight, 0)

    def forward(self, x):
        x = x.view(-1, 784)
        x = F.sigmoid(self.fc1(x))
        x = self.fc2(x)
        return x

model = Net()


criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.1)

num_epochs = 30
train_losses = []
test_losses = []
test_accuracies = []

for epoch in range(num_epochs):
    train_loss = 0.0
    for i, (images, labels) in enumerate(train_loader):
        outputs = model(images)
        loss = criterion(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
    else:
        test_loss = 0.0
        accuracy = 0
        with torch.no_grad():
            model.eval()
            for images, labels in test_loader:
                log_ps = model(images)
                test_loss += criterion(log_ps, labels).item()

                ps = log_ps
                top_p, top_class = ps.topk(1, dim=1)
                equals = top_class == labels.view(*top_class.shape)
                accuracy += torch.mean(equals.type(torch.FloatTensor))
        model.train()

        test_accuracy = accuracy/len(test_loader)
        test_accuracies.append(test_accuracy.item())

        train_losses.append(train_loss/len(train_loader))
        test_losses.append(test_loss/len(test_loader))

        print("Epoch: {}/{}.. ".format(epoch+1, num_epochs),
              "Training Loss: {:.3f}.. ".format(train_loss/len(train_loader)),
              "Test Loss: {:.3f}.. ".format(test_loss/len(test_loader)),
              "Test Accuracy: {:.3f}".format(test_accuracy))


plt.figure(figsize=(10, 5))
plt.plot(range(1, num_epochs+1), test_accuracies, color='blue')
plt.title('Test Accuracy vs. Epoch')
plt.xlabel('Epochs')
plt.ylabel('Test Accuracy')
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(range(1, num_epochs+1), test_losses, color='blue')
plt.title('Test Loss vs. Epoch')
plt.xlabel('Epochs')
plt.ylabel('Test Loss')
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(range(1, num_epochs+1), train_losses, color='blue')
plt.title('Training Loss vs. Epoch')
plt.xlabel('Epochs')
plt.ylabel('Training Loss')
plt.show()
# Out:
# Epoch: 1/30..  Training Loss: 2.328..  Test Loss: 2.283..  Test Accuracy: 0.114
# Epoch: 2/30..  Training Loss: 2.251..  Test Loss: 2.206..  Test Accuracy: 0.114
# Epoch: 3/30..  Training Loss: 2.174..  Test Loss: 2.138..  Test Accuracy: 0.114
# Epoch: 4/30..  Training Loss: 2.131..  Test Loss: 2.111..  Test Accuracy: 0.114
# Epoch: 5/30..  Training Loss: 2.108..  Test Loss: 2.091..  Test Accuracy: 0.114
# Epoch: 6/30..  Training Loss: 2.095..  Test Loss: 2.081..  Test Accuracy: 0.114
# Epoch: 7/30..  Training Loss: 2.085..  Test Loss: 2.073..  Test Accuracy: 0.114
# Epoch: 8/30..  Training Loss: 2.078..  Test Loss: 2.065..  Test Accuracy: 0.114
# Epoch: 9/30..  Training Loss: 2.073..  Test Loss: 2.061..  Test Accuracy: 0.114
# Epoch: 10/30..  Training Loss: 2.068..  Test Loss: 2.055..  Test Accuracy: 0.114
# Epoch: 11/30..  Training Loss: 2.063..  Test Loss: 2.051..  Test Accuracy: 0.114
# Epoch: 12/30..  Training Loss: 2.059..  Test Loss: 2.049..  Test Accuracy: 0.114
# ...

# %% [markdown]
# Question 4.4. ii)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torchvision import datasets, transforms
import matplotlib.pyplot as plt

transform = transforms.ToTensor()

train_dataset = datasets.MNIST(root = './mnist_data/',
                               train = True,
                               transform = transform,
                               download = True)
test_dataset = datasets.MNIST(root = './mnist_data/',
                              train = False,
                              transform = transform)

batch_size = 32
train_loader = torch.utils.data.DataLoader(dataset = train_dataset,
                                           batch_size = batch_size,
                                           shuffle = True)
test_loader = torch.utils.data.DataLoader(dataset = test_dataset,
                                          batch_size = batch_size,
                                          shuffle = False)

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(784, 300, bias = False)
        self.fc2 = nn.Linear(300, 10, bias = False)

        self.init_weights()

    def init_weights(self):
        nn.init.uniform_(self.fc1.weight, -1, 1)
        nn.init.uniform_(self.fc2.weight, -1, 1)

    def forward(self, x):
        x = x.view(-1, 784)
        x = F.sigmoid(self.fc1(x))
        x = self.fc2(x)
        return x

model = Net()

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

num_epochs = 30
train_losses = []
test_losses = []
test_accuracies = []

for epoch in range(num_epochs):

    train_loss = 0.0
    for i, (images, labels) in enumerate(train_loader):
        outputs = model(images)
        loss = criterion(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
    else:
        test_loss = 0.0
        accuracy = 0
        with torch.no_grad():
            model.eval()
            for images, labels in test_loader:
                log_ps = model(images)
                test_loss += criterion(log_ps, labels).item()

                ps = log_ps
                top_p, top_class = ps.topk(1, dim=1)
                equals = top_class == labels.view(*top_class.shape)
                accuracy += torch.mean(equals.type(torch.FloatTensor))
        model.train()

        test_accuracy = accuracy/len(test_loader)
        test_accuracies.append(test_accuracy.item())

        train_losses.append(train_loss/len(train_loader))
        test_losses.append(test_loss/len(test_loader))

        print("Epoch: {}/{}.. ".format(epoch+1, num_epochs),
              "Training Loss: {:.3f}.. ".format(train_loss/len(train_loader)),
              "Test Loss: {:.3f}.. ".format(test_loss/len(test_loader)),
              "Test Accuracy: {:.3f}".format(test_accuracy))


plt.figure(figsize=(10, 5))
plt.plot(range(1, num_epochs+1), test_accuracies, color='blue')
plt.title('Test Accuracy vs. Epoch')
plt.xlabel('Epochs')
plt.ylabel('Test Accuracy')
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(range(1, num_epochs+1), test_losses, color='blue')
plt.title('Test Loss vs. Epoch')
plt.xlabel('Epochs')
plt.ylabel('Test Loss')
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(range(1, num_epochs+1), train_losses, color='blue')
plt.title('Training Loss vs. Epoch')
plt.xlabel('Epochs')
plt.ylabel('Training Loss')
plt.show()
# Out:
# Epoch: 1/30..  Training Loss: 1.837..  Test Loss: 0.849..  Test Accuracy: 0.754
# Epoch: 2/30..  Training Loss: 0.736..  Test Loss: 0.603..  Test Accuracy: 0.826
# Epoch: 3/30..  Training Loss: 0.580..  Test Loss: 0.509..  Test Accuracy: 0.851
# Epoch: 4/30..  Training Loss: 0.503..  Test Loss: 0.453..  Test Accuracy: 0.868
# Epoch: 5/30..  Training Loss: 0.454..  Test Loss: 0.418..  Test Accuracy: 0.879
# Epoch: 6/30..  Training Loss: 0.419..  Test Loss: 0.392..  Test Accuracy: 0.886
# Epoch: 7/30..  Training Loss: 0.392..  Test Loss: 0.368..  Test Accuracy: 0.893
# Epoch: 8/30..  Training Loss: 0.370..  Test Loss: 0.353..  Test Accuracy: 0.899
# Epoch: 9/30..  Training Loss: 0.351..  Test Loss: 0.338..  Test Accuracy: 0.903
# Epoch: 10/30..  Training Loss: 0.336..  Test Loss: 0.325..  Test Accuracy: 0.907
# Epoch: 11/30..  Training Loss: 0.322..  Test Loss: 0.315..  Test Accuracy: 0.909
# Epoch: 12/30..  Training Loss: 0.310..  Test Loss: 0.306..  Test Accuracy: 0.912
# ...
